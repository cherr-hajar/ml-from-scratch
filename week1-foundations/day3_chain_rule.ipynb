# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def g(x):
    return x**2

def f(G):
    return 3*G + 1

x = 2
df_dg = 3
dg_dx = 2 * x

h = 0.0000000001
numerical = (f(g(x + h)) - f(g(x))) / h

print(numerical)
# Out:
# 12.000000992884452
