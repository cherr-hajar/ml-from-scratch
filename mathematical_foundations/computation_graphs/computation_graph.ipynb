# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(a, b, c):
    return (a+b)*c

# %%
h = 0.000001
a = 2
b = 3
c= 4
dea = (f(a+h, b, c) - f(a, b, c))/h
dec = (f(a, b, c+h) - f(a, b, c))/h
deb = (f(a, b+h, c) - f(a, b, c))/h
#backward pass
print(dea)
print(dec)
print(deb)
# Out:
# 4.000000000559112
# 5.000000001587068
# 4.000000000559112
